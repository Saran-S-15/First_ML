# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('price.csv')
df = df.drop('S.No',axis=1)
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area(sqrt ft)')
plt.ylabel('Price (US$)')
plt.scatter(df.Area,df.Price,color='red',marker='+')

# %%
reg = LinearRegression()
reg.fit(df[['Area']],df['Price'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
reg.predict(df[['Area']])
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
area=3700
reg.predict(np.array([[area]]))
# Out:
# /Users/kutty/Desktop/anaconda/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([683030.82191781])

# %%
# %matplotlib inline
plt.xlabel('Area(sqrt ft)')
plt.ylabel('Price (US$)')
plt.scatter(df.Area,df.Price,color='red',marker='+')
plt.plot(df.Area,reg.predict(df[['Area']]),color='blue',linewidth=1)

# %%
''' y=m*x+c '''
# Out:
# ' y=m*x+c '

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643
